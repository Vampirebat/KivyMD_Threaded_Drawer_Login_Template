# %% [markdown]
# <a href="https://colab.research.google.com/github/Vampirebat/KivyMD_Threaded_Drawer_Login_Template/blob/main/bloodback.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Basic Installs.

# %%
# !pip install pyrebase
# !pip install json
# !pip install firestore
# !pip install firebase_admin
# !pip install pandas
from os import times
import requests
import pyrebase
import firebase_admin
from firebase_admin import credentials
from firebase_admin import firestore
import json
import datetime
import pytz
utc=pytz.UTC
import pandas as pd

# %%
utctimenow = datetime.datetime.utcnow()
#print(utctimenow)

config = {
  "type": "service_account",
  "project_id": "bloodymoney-c7394",
  "private_key_id": "47d553273d5f81cd38447628c3bb3e8c9cf9a75e",
  "private_key": "-----BEGIN PRIVATE KEY-----\\n3wuiuAJFnqfzW/RgbLrpPGXJ\n-----END PRIVATE KEY-----\n",
  "client_email": "pythonbackend@bloodymoney-c7394.iam.gserviceaccount.com",
  "client_id": "112859134249798534429",
  "auth_uri": "https://accounts.google.com/o/oauth2/auth",
  "token_uri": "https://oauth2.googleapis.com/token",
  "auth_provider_x509_cert_url": "https://www.googleapis.com/oauth2/v1/certs",
  "client_x509_cert_url": "https://www.googleapis.com/robot/v1/metadata/x509/pythonbackend%40bloodymoney-c7394.iam.gserviceaccount.com",  
  "apiKey":'AIzaSyCfGicrXjFgpz2wLuc_qDzOpgsyoK-yKII',
  "authDomain": "bloodymoney-c7394.firebaseapp.com",
  "databaseURL": "https://console.firebase.google.com/u/0/project/bloodymoney-c7394/firestore/data/~2F",
  "storageBucket": "projectId.appspot.com",
  "serviceAccount": "bloodymoney-c7394-47d553273d5f.json"
}

#firebase = pyrebase.initialize_app(config)

# Use a service account
cred = credentials.Certificate('bloodymoney-c7394-47d553273d5f.json')
firebase_admin.initialize_app(cred)

db = firestore.client()


# doc_ref = db.collection(u'users').document(u'alovelace')
# doc_ref.set({
#     u'first': u'Ada',
#     u'last': u'Lovelace',
#     u'born': 1815
# })

# doc_ref = db.collection(u'users').document(u'aturing')
# doc_ref.set({
#     u'first': u'Alan',
#     u'middle': u'Mathison',
#     u'last': u'Turing',
#     u'born': 1912
# })

# users_ref = db.collection(u'acceptedPosts')
# docs = users_ref.stream()

# for doc in docs:
#     #print(f'{doc.id} => {doc.to_dict()}')
#     print({doc.id})
#     Document = doc.to_dict()
#     print(Document['reciept'])
#     rec1 = Document['reciept']
#     rec2 = Document['originalreciept']
    
# print(rec1)

# users_ref3 = db.collection(u'Posts')
# docs3 = users_ref3.stream()
# for doc3 in docs3:
#     Document3 = doc3.to_dict()
#     print(Document3['recipet'])
#     rec3 = Document3['recipet']
#     if rec3 == rec2:
#         print('found it')
#         print(doc3.id)   
    
def WriteDataToDatabase(GamePlayedStats,BetDetails,df,TotalPayout):
  print(type(TotalPayout[betdetails['OriginalPoster']]))
  wtbp = db.collection(u'Users')
  docs = wtbp.stream()
  for doc in docs:
    Document = doc.to_dict()

    docid = doc.id
    if betdetails['OriginalPoster'] == Document['display_name']:
      print(docid)
      credits_before = Document['credits']
      city_ref = db.collection(u'Users').document(docid)
      city_ref.set({
          u'credits': credits_before + TotalPayout[betdetails['OriginalPoster']]*2+TotalPayout['tie']
      }, merge=True)
    if betdetails['AcceptedPoster'] == Document['display_name']:
      print(docid)
      credits_before = Document['credits']
      city_ref = db.collection(u'Users').document(docid)
      city_ref.set({
          u'credits': credits_before + TotalPayout[betdetails['AcceptedPoster']]*2+TotalPayout['tie']
      }, merge=True)
  
  
  city_ref = db.collection(u'waitingtobeplayed').document(betdetails['matchdocumentid'])

  city_ref.set({
      u'Played_wait': True
  }, merge=True)
  print(betdetails)
  print(GamePlayedStats)
  print(df)

  index = df.index
  a_list = list(index)
  print(a_list)
  data = {
    u'poster': a_list[0],
    u'acceptor': a_list[1],
    u'poster_total_win': TotalPayout[betdetails['OriginalPoster']]*2+TotalPayout['tie'],
    u'acceptor_total_win': TotalPayout[betdetails['AcceptedPoster']]*2+TotalPayout['tie'],
    u'p_kills': int(df.iloc[0,2]),
    u'a_kills': int(df.iloc[1,2]),
    u'p_assists': int(df.iloc[0,4]),
    u'a_assists': int(df.iloc[1,4]),
    u'p_deaths': int(df.iloc[0,7]),
    u'a_deaths': int(df.iloc[1,7]),
    u'p_headshots': int(df.iloc[0,6]),
    u'a_headshots': int(df.iloc[1,6]),
    u'p_score': int(df.iloc[0,5]),
    u'a_score': int(df.iloc[1,5]),
    u'p_damage': int(df.iloc[0,3]),
    u'a_damage': int(df.iloc[1,3]),
    u'original_reciept': betdetails['reciept'],
    u'accepted_reciept': betdetails['acceptorreciept'],
    u'orig_post': betdetails['orig_record'],
    u'acc_post': betdetails['acc_record'],
    u'createdtime':datetime.datetime.utcnow()}
  ##################RANDOME
  db.collection('FinishedBets').document('LNSeQRkJpflmnDTL0Udh').set(data)
  

def checkgamesplayer(originalPoster,Accepter):
  url = "https://call-of-duty-modern-warfare.p.rapidapi.com/warzone-matches/%s/acti" % originalPoster
  headers = {
      'x-rapidapi-host': "call-of-duty-modern-warfare.p.rapidapi.com",
      'x-rapidapi-key': "1f5009c1c4mshdc548d9a0ba9351p1447dejsnb837212d74f5"
      }
  response = requests.request("GET", url, headers=headers)
  #print(response.text)
  #print(response.status_code)
  #print(response.headers)
  #print(type(response.text))
  result = json.loads(response.text)
  #print(result.keys())
  #print(result)
  original_all_matches =[]
  MatchCount = 0
  for match in result['matches']:
    originalmatches = {}
    # print(match['matchID'])
    # print(match['utcStartSeconds'])
    # print(match['playerStats']['kills'])
    # print(match['playerStats']['damageDone'])
    # print(match['playerStats']['assists'])
    # print(match['playerStats']['score'])
    # print(match['playerStats']['headshots'])
    # print(match['playerStats']['deaths'])

    originalmatches['Matchid'] = match['matchID']
    originalmatches['utcStartSeconds'] = match['utcStartSeconds']
    originalmatches['kills'] = match['playerStats']['kills']
    originalmatches['damageDone'] = match['playerStats']['damageDone']
    originalmatches['assists'] = match['playerStats']['assists']
    originalmatches['score'] = match['playerStats']['score']
    originalmatches['headshots'] = match['playerStats']['headshots']
    originalmatches['deaths'] = match['playerStats']['deaths']
    original_all_matches.append(originalmatches)
    MatchCount +=1
  #print(original_all_matches)



  url = "https://call-of-duty-modern-warfare.p.rapidapi.com/warzone-matches/%s/acti" % Accepter
  headers = {
      'x-rapidapi-host': "call-of-duty-modern-warfare.p.rapidapi.com",
      'x-rapidapi-key': "1f5009c1c4mshdc548d9a0ba9351p1447dejsnb837212d74f5"
      }
  response = requests.request("GET", url, headers=headers)
  #print(response.text)
  #print(response.status_code)
  #print(response.headers)
  #print(type(response.text))
  result = json.loads(response.text)
  #print(result.keys())
  #print(result['matches'][0])
  acceptor_all_matches =[]
  MatchCount = 0
  for match in result['matches']:
    acceptormatches = {}
    # print(match['matchID'])
    # print(match['utc        StartSeconds'])
    # print(match['playerStats']['kills'])
    # print(match['playerStats']['damageDone'])
    # print(match['playerStats']['assists'])
    # print(match['playerStats']['score'])
    # print(match['playerStats']['headshots'])
    # print(match['playerStats']['deaths'])

    acceptormatches['Matchid'] = match['matchID']
    acceptormatches['utcStartSeconds'] = match['utcStartSeconds']
    acceptormatches['kills'] = match['playerStats']['kills']
    acceptormatches['damageDone'] = match['playerStats']['damageDone']
    acceptormatches['assists'] = match['playerStats']['assists']
    acceptormatches['score'] = match['playerStats']['score']
    acceptormatches['headshots'] = match['playerStats']['headshots']
    acceptormatches['deaths'] = match['playerStats']['deaths']
    acceptor_all_matches.append(acceptormatches)
    MatchCount +=1
  #print(acceptor_all_matches)

  return original_all_matches, acceptor_all_matches
  

def who_won(postr,accptr,betdetails):
  
  gametimeepochtime = betdetails['GameTime'].timestamp()
  #print(gametimeepochtime)

  postrlist = []
  accptrlist = []
  for match in postr:
    postrlist.append(match['Matchid'])
  for match in accptr:
    accptrlist.append(match['Matchid'])
  #print(postr)
  #print(postrlist)
  #print(accptrlist)  

  #print(set(postrlist).intersection(accptrlist))

  #############  ADD A THING IF THEY DIDNT PLAY TOGETHER.
  sharedgames = set(postrlist).intersection(accptrlist)
  
  fulltime =[]
  for matchid in sharedgames:
    timeslistcomparisons ={}
    #print(matchid)
    postrsharedgame = next(item for item in postr if item["Matchid"] == matchid)
    accptrsharedgame = next(item for item in accptr if item["Matchid"] == matchid)

    timeslistcomparisons['Time'] = postrsharedgame['utcStartSeconds'] - gametimeepochtime

     
    
    timeslistcomparisons[betdetails['OriginalPoster']] = postrsharedgame
    timeslistcomparisons[betdetails['AcceptedPoster']] = accptrsharedgame
    fulltime.append(timeslistcomparisons)
  #print(fulltime)

  sorted_list = sorted(fulltime, key = lambda i: i['Time'],reverse=True)
  #print(sorted_list[0])
  
  df = pd.DataFrame.from_records(sorted_list[0]).fillna(0)
  df = df.T
  df.drop(labels='Time',axis=0,inplace=True)
  print(df)
  print('BET DEATIAls')
  print(betdetails)
  ### Track who is owed what
  winnerspayout = {}
  df['kills'] = pd.to_numeric(df['kills'])
  df['damageDone'] = pd.to_numeric(df['damageDone'])
  df['assists'] = pd.to_numeric(df['assists'])
  df['score'] = pd.to_numeric(df['score'])
  df['headshots'] = pd.to_numeric(df['headshots'])
  df['deaths'] = pd.to_numeric(df['deaths'])
  
  
  
  
  
  
  ##get who won kills
  tie = df.iloc[0,2] == (df.iloc[1,2])
  if tie == False:
    MostKills = df["kills"]
    kills = MostKills.max()
    killswinner = MostKills.idxmax() 
  
    killsloser = MostKills.idxmin()
    
    # print(kills)
    # print(killswinner)
    # print(betdetails['MostKills'])
    winnerspayout['MostKills'] = [killswinner,betdetails['MostKills'],killsloser,0]
  else:
    winnerspayout['MostKills'] = ['tie',0]
  
  ##get who won damagedone
  tie = df.iloc[0,3] == (df.iloc[1,3])
  if tie == False:
    MostdamageDone = df["damageDone"]
    damageDone = MostdamageDone.max()
    damageDonewinner = MostdamageDone.idxmax() 
    damageloser = MostdamageDone.idxmin()
    winnerspayout['MostdamageDone'] = [damageDonewinner,betdetails['MostDamage'],damageloser,0]
  else:
    winnerspayout['MostdamageDone'] = ['tie',0]
  
  ##get who won MostAssists
  tie = df.iloc[0,4] == (df.iloc[1,4])
  if tie == False:
    MostAssists = df["assists"]
    daMostAssists = MostAssists.max()
    MostAssistswinner = MostAssists.idxmax()
    assistsloser = MostAssists.idxmin()
     
  
    winnerspayout['MostAssists'] = [MostAssistswinner,betdetails['MostAssists'],assistsloser,0]
  else:
    winnerspayout['MostAssists'] = ['tie',betdetails['MostAssists']]
  

  ##get who won score
  tie = df.iloc[0,5] == (df.iloc[1,5])
  if tie == False:
    Mostscore = df["score"]
    daMostscore = Mostscore.max()
    Mostscorewinner = Mostscore.idxmax()
    Mostscoreloser = Mostscore.idxmin() 
  
    winnerspayout['HighestScore'] = [Mostscorewinner,betdetails['HighestScore'],Mostscoreloser,0]
  else:
    winnerspayout['HighestScore'] = ['tie',betdetails['HighestScore']]


  ##get who won headshots
  tie = df.iloc[0,6] == (df.iloc[1,6])
  if tie == False:
    Mostheadshots = df["headshots"]
    daMostheadshots = Mostheadshots.max()
    Mostheadshotswinner = Mostheadshots.idxmax()
    Mostheadshotsloser = Mostheadshots.idxmin() 
  
    winnerspayout['MostHeadshots'] = [Mostheadshotswinner,betdetails['MostHeadshots'],Mostheadshotsloser,0]
  else:
    winnerspayout['MostHeadshots'] = ['tie',betdetails['MostHeadshots']]

  ##get who won deaths
  tie = df.iloc[0,7] == (df.iloc[1,7])
  if tie == False:
    leastdeaths = df["deaths"]
    daleastdeaths = leastdeaths.min()
    leastdeathswinner = leastdeaths.idxmin()
    leastdeathsloser = leastdeaths.idxmax() 
  
    winnerspayout['LeastDeaths'] = [leastdeathswinner,betdetails['LeastDeaths'],leastdeathsloser,0]
  else:
    winnerspayout['LeastDeaths'] = ['tie',betdetails['LeastDeaths']]
  
  print('WINNERS PAYOUT')
  print(winnerspayout)

  ### add up winnings.
  
  TotalPayout = {betdetails['OriginalPoster']:0,betdetails['AcceptedPoster']:0,'tie':0}
  
  if betdetails['OriginalPoster'] == winnerspayout['MostKills'][0]:
    TotalPayout[betdetails['OriginalPoster']] += betdetails['MostKills']
  if betdetails['AcceptedPoster'] == winnerspayout['MostKills'][0]:
    TotalPayout[betdetails['AcceptedPoster']] += betdetails['MostKills']
  if 'tie' == winnerspayout['MostKills'][0]:
    TotalPayout['tie'] += betdetails['MostKills']
   
  if betdetails['OriginalPoster'] == winnerspayout['MostdamageDone'][0]:
    TotalPayout[betdetails['OriginalPoster']] += betdetails['MostDamage']
  if betdetails['AcceptedPoster'] == winnerspayout['MostdamageDone'][0]:
    TotalPayout[betdetails['AcceptedPoster']] += betdetails['MostDamage']
  if 'tie' == winnerspayout['MostdamageDone'][0]:
    TotalPayout['tie'] += betdetails['MostDamage']
  
  if betdetails['OriginalPoster'] == winnerspayout['MostAssists'][0]:
    TotalPayout[betdetails['OriginalPoster']] += betdetails['MostAssists']
  if betdetails['AcceptedPoster'] == winnerspayout['MostAssists'][0]:
    TotalPayout[betdetails['AcceptedPoster']] += betdetails['MostAssists']
  if 'tie' == winnerspayout['MostAssists'][0]:
    TotalPayout['tie'] += betdetails['MostAssists']
  
  if betdetails['OriginalPoster'] == winnerspayout['HighestScore'][0]:
    TotalPayout[betdetails['OriginalPoster']] += betdetails['HighestScore']
  if betdetails['AcceptedPoster'] == winnerspayout['HighestScore'][0]:
    TotalPayout[betdetails['AcceptedPoster']] += betdetails['HighestScore']
  if 'tie' == winnerspayout['HighestScore'][0]:
    TotalPayout['tie'] += betdetails['HighestScore']
  
  if betdetails['OriginalPoster'] == winnerspayout['MostHeadshots'][0]:
    TotalPayout[betdetails['OriginalPoster']] += betdetails['MostHeadshots']
  if betdetails['AcceptedPoster'] == winnerspayout['MostHeadshots'][0]:
    TotalPayout[betdetails['AcceptedPoster']] += betdetails['MostHeadshots']
  if 'tie' == winnerspayout['MostHeadshots'][0]:
    TotalPayout['tie'] += betdetails['MostHeadshots']
  
  if betdetails['OriginalPoster'] == winnerspayout['LeastDeaths'][0]:
    TotalPayout[betdetails['OriginalPoster']] += betdetails['LeastDeaths']
  if betdetails['AcceptedPoster'] == winnerspayout['LeastDeaths'][0]:
    TotalPayout[betdetails['AcceptedPoster']] += betdetails['LeastDeaths']
  if 'tie' == winnerspayout['LeastDeaths'][0]:
    TotalPayout['tie'] += betdetails['LeastDeaths']
  
  print('TOTAL PAYOUT')
  print(TotalPayout)
  #
  WriteDataToDatabase(winnerspayout,betdetails,df,TotalPayout)
  
  
  
  
  
  # timeslist ={}
  # i=0
  # for post in postr:  
  #   for x in sharedgames:
  #     if postr[i]['Matchid'] == x:
  #       print('found it')
  #       print(postr[i])
  #       proximity = gametimeepochtime - postr[i]['utcStartSeconds']
  #       timeslist['proximity'] = proximity

        

  #   i+=1
  # print(timeslist)
  #epoch_time = 1571005498
  #datetime_time = datetime.datetime.fromtimestamp(epoch_time)

  # import pandas as pd

  # df=pd.DataFrame(postr)
  # df2=pd.DataFrame(accptr)

  # print(df.Matchid.isin(df2.Matchid))  




# 'utcStartSeconds'
# 'utcEndSeconds'
# 'map'
# 'mode'
# 'matchID'
# 'duration'
# 'playlistName'
# 'gameType'
# 'playerStats':{}
# print(result['matches'][0]['playerStats'])
## 'kills'
# 'kdRatio'
# 'wallBangs'
## 'score'
## 'headshots'
# 'executions'
## 'assists'
# 'nearmisses'
# 'percentTimeMoving'
#  'longestStreak'
#  'scorePerMinute'
## 'damageDone'
# 'distanceTraveled'
## 'deaths'
# 'damageTaken'
# x=0
# for i in range(20):
#     print(result['matches'][x]['matchID'])
#     print(result['matches'][x]['playerStats']['kills'])
#     x+=1







#######################
## Get the waiting to be played list... and find matching posts...# 
wtbp = db.collection(u'waitingtobeplayed')
docs = wtbp.stream()

for doc in docs:
    #print(f'{doc.id} => {doc.to_dict()}')
    #print({doc.id})
    document_id = doc.id
    Document = doc.to_dict()
    #print(type(Document['GameTime']))
    #print(type(utctimenow))
    #print(Document)
    #print(Document)
    gametime = Document['GameTime']
    gametime  = gametime.replace(tzinfo=utc)
    utctimenow = utctimenow.replace(tzinfo=utc) 
    if gametime < utctimenow:
      print('past')
      if Document['Played_wait'] == False:
        print('Gotta check games to see matching')
        ### Get user names to compare if they are in same game
        matchdocumentid = document_id
        accepted = Document['acceptedPost'].id
        original = Document['originalPost'].id
        ### Get Accepted Document
        getaccepted = db.collection(u'acceptedPosts').document(accepted)
        acceptedDoc = getaccepted.get()
        accDocument = acceptedDoc.to_dict()
        #print(accDocument['display_name'])

        ### Get Original DOcument
        getOriginal = db.collection(u'Posts').document(original)
        originalDoc = getOriginal.get()
        origDocument = originalDoc.to_dict()
        ### Get Accepted DOcument
        getAccepted = db.collection(u'acceptedPosts').document(accepted)
        AcceptedDoc = getAccepted.get()
        AcceptedDoc= AcceptedDoc.to_dict()
        print(AcceptedDoc['display_name'])
        print(origDocument['PostCreator'])
        #print(origDocument)
        #### get bet information
        betdetails = {}
        betdetails['matchdocumentid'] = matchdocumentid
        betdetails['acceptedPosterPostid'] = Document['acceptedPost'].id
        betdetails['originalPosterPostid'] = Document['originalPost'].id
        betdetails['OriginalPoster'] = origDocument['PostCreator']
        betdetails['AcceptedPoster'] = AcceptedDoc['display_name']
        betdetails['reciept'] = origDocument['recipet']
        betdetails['acceptorreciept'] = AcceptedDoc['reciept']
        betdetails['MostKills'] = origDocument['MostKills']
        betdetails['LeastDeaths'] = origDocument['LeastDeaths']
        betdetails['MostDamage'] = origDocument['MostDamage']
        betdetails['HighestScore'] = origDocument['HighestScore']
        betdetails['MostAssists'] = origDocument['MostAssists']
        betdetails['MostHeadshots'] = origDocument['MostHeadshots']
        betdetails['totalbet'] = origDocument['totalbet']
        betdetails['GameTime'] = origDocument['GameTime']
        betdetails['GameType'] = origDocument['GameType']
        betdetails['GameStyle'] = origDocument['GameStyle']
        betdetails['orig_record'] = Document['originalPost']
        betdetails['acc_record'] = Document['acceptedPost']
        

        #get activision name
        print(accDocument['originalPoster'])
        getOriUser = db.collection(u'Users').document(accDocument['originalPoster'].id)
        OriUser = getOriUser.get()
        OriActivision= OriUser.to_dict()
        originalPoster=OriActivision['activisionid']
        originalPoster = originalPoster.replace('#','%23')
        print(originalPoster)

        getAccUser = db.collection(u'Users').document(accDocument['acceptedBy'].id)
        AccUser = getAccUser.get()
        AccActivision= AccUser.to_dict()
        Acceptor=AccActivision['activisionid']
        Acceptor = Acceptor.replace('#','%23')
        
        


        #originalPoster='Vampyre%235007497'
        originalPoster_platform=''
        #Acceptor='MeloYello%236035519'
        #Acceptor='meloyello%2311864'
        ###check if they played together
        
        postr, accptr = checkgamesplayer(originalPoster,Acceptor)
        
        
        
        who_won(postr,accptr,betdetails)

    else:
      print('not past')



    
def checkiflive():
  +1
def checkaddress():
  +1
def addgifts():
  +1
def shipgifts():
  +1
    

  


def Checkifthereinsamegame():
  +1

def CheckWhoWon():
  +1

  



# {'reciept': 'XcjkN0p1argAxlfFkUqY9WLEvL52Tuesday, December 216:40 PMVerdansk Quads0Netore Mining', 
# 'originalreciept': 'ly9JPYgkRmbZMPcPyg2AYJtsBm73Tuesday, December 211:44 PMNetore MiningVerdansk Quads0', 
# 'acceptedBy': <google.cloud.firestore_v1.document.DocumentReference object at 0x000001B5E7A1FF10>, 
# 'display_name': 'Goth', 
# 'acceperphotourl': 'https://lh3.googleusercontent.com/a-/AOh14GjMrdx6Q06yHBfZ4dlnIkGL2QA9K-QY6Qf63IIP=s96-c', 
# 'originalPoster': <google.cloud.firestore_v1.document.DocumentReference object at 0x000001B5E7A1FFA0>, 
# 'uid': 'ly9JPYgkRmbZMPcPyg2AYJtsBm73', 
# 'originalname': 'Netore Mining', 
# 'acceptedname': 'Goth', 
# 'created_time': DatetimeWithNanoseconds(2021, 12, 22, 2, 40, 10, 684000, tzinfo=datetime.timezone.utc), 
# 'confirmed': True, 
# 'originalPOST': <google.cloud.firestore_v1.document.DocumentReference object at 0x000001B5E7A1FCA0>, 
# 'originalpic': 'https://lh3.googleusercontent.com/a-/AOh14Ghkah2STbH-L0fW9WngBREar489lilTvlG_VLp2=s96-c', 
# 'accepteruid': 'XcjkN0p1argAxlfFkUqY9WLEvL52', 'acceptedDate': DatetimeWithNanoseconds(2021, 12, 
# 22, 2, 40, 10, 684000, tzinfo=datetime.timezone.utc), 
# 'acceptedbydislplayname': 'Goth', 
# 'played': False, 
# 'totalbet': 0}


# {'tw': 'twitch', 
# 'MostDamage': 0, 
# 'display_name': 'Netore Mining', 
# 'winner': 'notyet', 
# 'Map': 'cod', 
# 'totalbet': 0, 
# 'PlayStyle': 'Same Game', 
# 'Image': 'https://lh3.googleusercontent.com/a-/AOh14Ghkah2STbH-L0fW9WngBREar489lilTvlG_VLp2=s96-c', 
# 'GameDay': DatetimeWithNanoseconds(2021, 12, 22, 7, 4, tzinfo=datetime.timezone.utc), 
# 'twitch': '', 
# 'GameStyle': '1on1', 
# 'readytoplay': True, 
# 'BetAmount': 0, 
# 'photo_url': 'https://lh3.googleusercontent.com/a-/AOh14Ghkah2STbH-L0fW9WngBREar489lilTvlG_VLp2=s96-c',
# 'email': '******O@gmail.com', 
# 'confirmed': False, 
# 'LeastDeaths': 0, 
# 'PostersCoins': 424, 
# 'UserName': <google.cloud.firestore_v1.document.DocumentReference object at 0x000001B5E7A1F880>, 
# 'TimePosted': DatetimeWithNanoseconds(2021, 12, 21, 21, 44, 43, 708000, tzinfo=datetime.timezone.utc), 
# 'MostAssists': 0, 
# 'recipet': 'ly9JPYgkRmbZMPcPyg2AYJtsBm73Tuesday, December 211:44 PMNetore MiningVerdansk Quads0', 
# 'CodGameModes': ['coo'], 
# 'TeamSetup': '1 vs 2', 
# 'phone_number': '', 
# 'acceptedby2': 'no', 
# 'PostDate': DatetimeWithNanoseconds(2021, 12, 21, 21, 44, 43, 708000, tzinfo=datetime.timezone.utc), 
# 'GameType': 'Verdansk Quads', 
# 'TeamMembersAdded': [<google.cloud.firestore_v1.document.DocumentReference object at 0x000001B5E7A1F490>], 
# 'ChallengersCoins': 0, 
# 'PostCreator': 'Netore Mining', 
# 'Played': False, 
# 'HighestScore': 0, 
# 'uid': 'ly9JPYgkRmbZMPcPyg2AYJtsBm73', 
# 'MostKills': 0, 
# 'MostHeadshots': 0, 
# 'CtreatedBy': <google.cloud.firestore_v1.document.DocumentReference object at 0x000001B5E7A1FB50>, 
# 'GameTime': DatetimeWithNanoseconds(2021, 12, 22, 7, 4, tzinfo=datetime.timezone.utc)}






    #docaccept = doc_ref.get()
    #print(Document['reciept'])
    #rec1 = Document['reciept']
    #rec2 = Document['originalreciept']
# Out:
# past
# past
# past
